# %% [markdown]
# ## Object classification using the pre-trained VGG model

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
model = VGG16()
#Load an image
image = load_img('img.jpg', target_size=(224, 224))
#Convert the image pixels to a numpy array
image = img_to_array(image)
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
#Prepare image for VGG model
yhat = model.predict(image)
label = decode_predictions(yhat, top=1000)
label = label[0][:]
print (label)
# Out:
# Using TensorFlow backend.
# [('n04252225', 'snowplow', 0.93203205), ('n03967562', 'plow', 0.028035149), ('n04252077', 'snowmobile', 0.02069668), ('n03594945', 'jeep', 0.008972278), ('n04465501', 'tractor', 0.003224843), ('n04208210', 'shovel', 0.0023375181), ('n03218198', 'dogsled', 0.0012060637), ('n03496892', 'harvester', 0.0011941277), ('n02704792', 'amphibian', 0.00053060346), ('n04461696', 'tow_truck', 0.00044557848), ('n03478589', 'half_track', 0.00037068347), ('n04204347', 'shopping_cart', 0.0002265046), ('n04606251', 'wreck', 0.00018053871), ('n04428191', 'thresher', 8.041907e-05), ('n04467665', 'trailer_truck', 4.8836682e-05), ('n03000684', 'chain_saw', 4.2577994e-05), ('n03126707', 'crane', 3.594386e-05), ('n03240683', 'drilling_platform', 3.1907028e-05), ('n04228054', 'ski', 2.9381887e-05), ('n02797295', 'barrow', 2.8984627e-05), ('n03649909', 'lawn_mower', 2.8636292e-05), ('n03417042', 'garbage_truck', 2.0851989e-05), ('n03384352', 'forklift', 1.544276e-05), ('n03891251', 'park_bench', 1.449807e-05), ('n04273569', 'speedboat', 1.177723e-05), ('n02981792', 'catamaran', 9.247546e-06), ('n03662601', 'lifeboat', 8.61104e-06), ('n03930630', 'pickup', 7.1274976e-06), ('n03444034', 'go-kart', 6.6335047e-06), ('n04371774', 'swing', 5.4037714e-06), ('n03445924', 'golfcart', 4.396588e-06), ('n09421951', 'sandbar', 4.1089734e-06), ('n04118776', 'rule', 3.887275e-06), ('n04179913', 'sewing_machine', 3.6942918e-06), ('n02093859', 'Kerry_blue_terrier', 3.4711877e-06), ('n02894605', 'breakwater', 3.4264672e-06), ('n02747177', 'ashcan', 3.1004627e-06), ('n03482405', 'hamper', 2.938722e-06), ('n04482393', 'tricycle', 2.581694e-06), ('n04336792', 'stretcher', 2.4939206e-06), ('n02860847', 'bobsled', 2.4683445e-06), ('n04483307', 'trimaran', 2.4405765e-06), ('n04389033', 'tank', 2.3992357e-06), ('n06359193', 'web_site', 2.2472263e-06), ('n02092002', 'Scottish_deerhound', 2.1455514e-06), ('n10565667', 'scuba_diver', 1.9979432e-06), ('n02097130', 'giant_schnauzer', 1.9246254e-06), ('n02837789', 'bikini', 1.8996193e-06), ('n03888257', 'parachute', 1.8164434e-06), ('n03532672', 'hook', 1.803052e-06), ('n04371430', 'swimming_trunks', 1.7522024e-06), ('n03908714', 'pencil_sharpener', 1.6928515e-06), ('n04507155', 'umbrella', 1.6208068e-06), ('n09428293', 'seashore', 1.4820474e-06), ('n03803284', 'muzzle', 1.4621628e-06), ('n03345487', 'fire_engine', 1.4334663e-06), ('n02807133', 'bathing_cap', 1.4094079e-06), ('n03710721', 'maillot', 1.406301e-06), ('n04019541', 'puck', 1.2853359e-06), ('n03873416', 'paddle', 1.1891414e-06), ('n09193705', 'alp', 1.0896358e-06), ('n01978455', 'rock_crab', 1.0751032e-06), ('n03976467', 'Polaroid_camera', 1.0627351e-06), ('n02090721', 'Irish_wolfhound', 1.0046049e-06), ('n04347754', 'submarine', 8.8609073e-07), ('n02974003', 'car_wheel', 8.7671594e-07), ('n03933933', 'pier', 8.5870573e-07), ('n03794056', 'mousetrap', 8.292217e-07), ('n03777568', 'Model_T', 7.9534027e-07), ('n02701002', 'ambulance', 7.794706e-07), ('n03538406', 'horse_cart', 7.5388385e-07), ('n01665541', 'leatherback_turtle', 7.350491e-07), ('n02092339', 'Weimaraner', 6.997045e-07), ('n02317335', 'starfish', 6.9890683e-07), ('n02672831', 'accordion', 6.946415e-07), ('n03871628', 'packet', 6.8346003e-07), ('n03376595', 'folding_chair', 6.484547e-07), ('n04548362', 'wallet', 6.34386e-07), ('n02099712', 'Labrador_retriever', 6.1764496e-07), ('n04266014', 'space_shuttle', 6.0268565e-07), ('n03792972', 'mountain_tent', 5.9545175e-07), ('n04152593', 'screen', 5.184971e-07), ('n02814533', 'beach_wagon', 5.1783496e-07), ('n02099429', 'curly-coated_retriever', 5.0595514e-07), ('n09332890', 'lakeside', 5.004341e-07), ('n04026417', 'purse', 4.9709354e-07), ('n03666591', 'lighter', 4.861335e-07), ('n03874293', 'paddlewheel', 4.8074946e-07), ('n03014705', 'chest', 4.6814267e-07), ('n02107574', 'Greater_Swiss_Mountain_dog', 4.5500647e-07), ('n04037443', 'racer', 4.5169816e-07), ('n02978881', 'cassette', 4.4980328e-07), ('n02091134', 'whippet', 4.4199814e-07), ('n02909870', 'bucket', 4 ...

# %%
model = VGG16()
image = load_img('img.jpg', target_size=(224, 224))
image = img_to_array(image)
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
image = preprocess_input(image)
yhat = model.predict(image)
label = decode_predictions(yhat, top=1000)
#Making minor changes to predict label with highest probability
label = label[0][0]
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# snowplow (97.13%)

# %% [markdown]
# ### Does the script work ? - yes indeed

# %%
from IPython.display import Image
Image("img.jpg")
